# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df=pd.read_csv("/Users/wojtekmarszalek/Desktop/Sales Data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        185950 non-null  int64
#  1   Order ID          185950 non-null  int64
#  2   Product           185950 non-null  object
#  3   Quantity Ordered  185950 non-null  int64
#  4   Price Each        185950 non-null  float64
#  5   Order Date        185950 non-null  object
#  6   Purchase Address  185950 non-null  object
#  7   Month             185950 non-null  int64
#  8   Sales             185950 non-null  float64
#  9   City              185950 non-null  object
#  10  Hour              185950 non-null  int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 15.6+ MB

# %%
df.head(15)
# Out:
#     Unnamed: 0  Order ID                     Product  Quantity Ordered  \
# 0            0    295665          Macbook Pro Laptop                 1
# 1            1    295666          LG Washing Machine                 1
# 2            2    295667        USB-C Charging Cable                 1
# 3            3    295668            27in FHD Monitor                 1
# 4            4    295669        USB-C Charging Cable                 1
# 5            5    295670       AA Batteries (4-pack)                 1
# 6            6    295671        USB-C Charging Cable                 1
# 7            7    295672        USB-C Charging Cable                 2
# 8            8    295673  Bose SoundSport Headphones                 1
# 9            9    295674      AAA Batteries (4-pack)                 4
# 10          10    295675        USB-C Charging Cable                 2
# 11          11    295676             ThinkPad Laptop                 1
# ...

# %%
df["Order Date"]=pd.to_datetime(df["Order Date"]).dt.date

# %%
df.drop("Unnamed: 0",inplace=True,axis=1)

# %%
df[["Street", "City", "Postal Code"]]=df['Purchase Address'].str.split(",", expand=True)

# %%
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#         Order Date                        Purchase Address  Month    Sales  \
# ...

# %%
df.drop("Purchase Address", inplace=True, axis=1)

# %%
days=[]
for i in df["Order Date"]:
    days.append(i.day)

# %%
df["Day"]=days

# %%
df.drop("Order Date", axis=1, inplace=True)

# %%
df=df[["Order ID", "Product","Quantity Ordered", "Month", "Day", "Price Each", "Sales", "City", "Hour", "Street", "Postal Code"]]

# %%
df
# Out:
#         Order ID                 Product  Quantity Ordered  Month  Day  \
# 0         295665      Macbook Pro Laptop                 1     12   30
# 1         295666      LG Washing Machine                 1     12   29
# 2         295667    USB-C Charging Cable                 1     12   12
# 3         295668        27in FHD Monitor                 1     12   22
# 4         295669    USB-C Charging Cable                 1     12   18
# ...          ...                     ...               ...    ...  ...
# 185945    222905  AAA Batteries (4-pack)                 1      6    7
# 185946    222906        27in FHD Monitor                 1      6    1
# 185947    222907    USB-C Charging Cable                 1      6   22
# 185948    222908    USB-C Charging Cable                 1      6   26
# 185949    222909  AAA Batteries (4-pack)                 1      6   25
#
#         Price Each    Sales            City  Hour         Street Postal Code
# ...
